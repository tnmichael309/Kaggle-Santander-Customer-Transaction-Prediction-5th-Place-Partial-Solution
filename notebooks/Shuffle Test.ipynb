# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
import gc
from tqdm import tqdm; tqdm.pandas()

# %%
train = pd.read_pickle('data/train_original.pkl')
test = pd.read_pickle('data/test_original.pkl')
special_cols = [col for col in train.columns if train[col].dtype != np.float64]
feature_cols = [col for col in train.columns if col not in special_cols]

# %%
train_df = train.copy()
test_df = test.copy()

# %%
train_df_0 = train_df.loc[train_df.target==0, feature_cols].reset_index(drop=True)
train_df_1 = train_df.loc[train_df.target==1, feature_cols].reset_index(drop=True)

# %%
train_df_0.head(3)
# Out:
#      var_0   var_1    var_2   var_3    var_4   var_5   var_6    var_7   var_8  \
# 0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187  18.6266 -4.9200
# 1  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208  16.5338  3.1468
# 2   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427  14.6155 -4.9193
#
#     var_9   ...     var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  5.7470   ...      4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  8.0851   ...      7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  5.9525   ...      2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
#
#    var_196  var_197  var_198  var_199
# 0   7.8784   8.5635  12.7803  -1.0914
# 1   8.1267   8.7889  18.3560   1.9518
# 2  -6.5213   8.2675  14.7222   0.3965
#
# [3 rows x 200 columns]

# %%
import random; random.seed(0)
from random import shuffle

# shuffle by row
train_df_0.loc[:,:] = np.array([np.array(v) for v in train_df_0.progress_apply(np.random.permutation, axis=1)]) 
train_df_1.loc[:,:] = np.array([np.array(v) for v in train_df_1.progress_apply(np.random.permutation, axis=1)]) 

# shuffle by col
'''
for df in [train_df_0, train_df_1]:
    for col in tqdm(feature_cols):
        vals = df[col].values
        shuffle(vals)
        df.loc[:,col] = vals
'''
# Out:
# 100%|███████████████████████████████████████████████████████████████████| 179902/179902 [00:09<00:00, 19035.23it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 20098/20098 [00:01<00:00, 19493.70it/s]
# '\nfor df in [train_df_0, train_df_1]:\n    for col in tqdm(feature_cols):\n        vals = df[col].values\n        shuffle(vals)\n        df.loc[:,col] = vals\n'

# %%
train_df_0.head(3)
# Out:
#     var_0    var_1   var_2    var_3    var_4    var_5    var_6    var_7  \
# 0  9.0164  11.2663 -0.2154  11.1920  13.3102  12.8287  -9.2834  13.7241
# 1  0.8194  34.4014  6.8852  13.7814  13.9550  31.5899  40.5632   3.3716
# 2  5.8200  -0.9479  6.8874   9.5413   1.1000  12.6317  21.1613  -5.5952
#
#     var_8   var_9   ...     var_190  var_191  var_192  var_193  var_194  \
# 0 -6.7863  5.8764   ...     -1.0914   2.0771   5.3253   4.2218   3.1364
# 1 -4.8622  1.7093   ...     11.0752   0.1225  -4.8210  11.7700   7.0118
# 2  2.3612  9.7905   ...     -3.9116   4.5255   5.7033  12.9143   3.1417
#
#    var_195  var_196  var_197  var_198  var_199
# 0  -3.4132  10.5350  16.1828   7.8871  11.0924
# 1   5.3890  11.5006   8.4068   2.2302  13.8910
# 2  10.1852   6.9346  20.5092   6.9427   3.6932
#
# [3 rows x 200 columns]

# %%
train_df_0.shape, train_df_1.shape
# Out:
# ((179902, 200), (20098, 200))

# %%
# combine
train_df_0['target'] = 0
train_df_1['target'] = 1
train_df = pd.concat([train_df_0, train_df_1]).reset_index(drop=True)
train_df = train_df.sample(frac=1).reset_index(drop=True)

# %%
train_df.shape
# Out:
# (200000, 201)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
import lightgbm as lgb
import time

params = {'num_leaves': 8,
         'min_data_in_leaf': 42,
         'objective': 'binary',
         'max_depth': 16,
         'learning_rate': 0.03,
         'boosting': 'gbdt',
         'bagging_freq': 5,
         'bagging_fraction': 0.8,
         'feature_fraction': 0.8201,
         'bagging_seed': 11,
         'reg_alpha': 1.7289,
         'reg_lambda': 4.984,
         'random_state': 42,
         'metric': 'binary_logloss',
         'verbosity': -1,
         'subsample': 0.81,
         'min_gain_to_split': 0.01,
         'min_child_weight': 19.428,
         'num_threads': 2}

oof = np.zeros(len(train))
prediction = np.zeros(len(test))

n_fold = 10
folds = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=42)
feature_importance_df = pd.DataFrame()

for fold_n, (train_index, valid_index) in enumerate(folds.split(train_df.target.values,train_df.target.values)):
    
    print('Fold', fold_n, 'started at', time.ctime())
    X_train, X_valid = train_df.loc[train_index, feature_cols], train_df.loc[valid_index, feature_cols]
    y_train, y_valid = train_df.target.values[train_index], train_df.target.values[valid_index]
    
    train_data = lgb.Dataset(X_train, label=y_train)
    valid_data = lgb.Dataset(X_valid, label=y_valid)
        
    model = lgb.train(params,train_data, num_boost_round=3200,
                    valid_sets = [train_data, valid_data], verbose_eval=100,
                    early_stopping_rounds = 200)
     
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = feature_cols
    fold_importance_df["importance"] = model.feature_importance(importance_type='gain')
    fold_importance_df["fold"] = fold_n + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)    
       
    oof[valid_index] = model.predict(X_valid, num_iteration=model.best_iteration)
    prediction += model.predict(test_df[feature_cols], num_iteration=model.best_iteration)/n_fold
    gc.collect()
    print(roc_auc_score(y_valid, oof[valid_index]))
    
full_auc = roc_auc_score(train_df.target.values, oof)
print(full_auc)
# Out:
# Fold 0 started at Sat Mar 16 11:54:23 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.324511	valid_1's binary_logloss: 0.326241
# [200]	training's binary_logloss: 0.323008	valid_1's binary_logloss: 0.326287
# Early stopping, best iteration is:
# [25]	training's binary_logloss: 0.325716	valid_1's binary_logloss: 0.326122
# 0.5088445687741604
# Fold 1 started at Sat Mar 16 11:54:42 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.324512	valid_1's binary_logloss: 0.326323
# [200]	training's binary_logloss: 0.323039	valid_1's binary_logloss: 0.326365
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.326138	valid_1's binary_logloss: 0.32617
# 0.5021421158340365
# Fold 2 started at Sat Mar 16 11:55:00 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.324533	valid_1's binary_logloss: 0.326159
# [200]	training's binary_logloss: 0.323028	valid_1's binary_logloss: 0.326191
# Early stopping, best iteration is:
# [45]	training's binary_logloss: 0.325391	valid_1's binary_logloss: 0.326083
# 0.5163600286505217
# Fold 3 started at Sat Mar 16 11:55:20 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.324514	valid_1's binary_logloss: 0.32605
# [200]	training's binary_logloss: 0.322984	valid_1's binary_logloss: 0.325933
# [300]	training's binary_logloss: 0.321584	valid_1's binary_logloss: 0.325851
# [400]	training's binary_logloss: 0.320191	valid_1's binary_logloss: 0.325929
# [500]	training's binary_logloss: 0.318828	valid_1's binary_logloss: 0.325951
# Early stopping, best iteration is:
# [303]	training's binary_logloss: 0.321544	valid_1's binary_logloss: 0.325836
# 0.5231144997635502
# Fold 4 started at Sat Mar 16 11:55:54 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.324514	valid_1's binary_logloss: 0.326035
# [200]	training's binary_logloss: 0.323027	valid_1's binary_logloss: 0.326035
# [300]	training's binary_logloss: 0.321588	valid_1's binary_logloss: 0.326003
# [400]	training's binary_logloss: 0.320215	valid_1's binary_logloss: 0.325931
# [500]	training's binary_logloss: 0.318862	valid_1's binary_logloss: 0.325931
# [600]	training's binary_logloss: 0.317524	valid_1's binary_logloss: 0.326078
# [700]	training's binary_logloss: 0.31623	valid_1's binary_logloss: 0.326068
# Early stopping, best iteration is:
# [513]	training's binary_logloss: 0.318688	valid_1's binary_logloss: 0.325915
# 0.5236797391585707
# Fold 5 started at Sat Mar 16 11:56:40 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.324533	valid_1's binary_logloss: 0.32628
# [200]	training's binary_logloss: 0.323042	valid_1's binary_logloss: 0.326363
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.326135	valid_1's binary_logloss: 0.326182
# 0.500744955046889
# Fold 6 started at Sat Mar 16 11:56:57 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.32452	valid_1's binary_logloss: 0.326098
# [200]	training's binary_logloss: 0.323034	valid_1's binary_logloss: 0.326017
# [300]	training's binary_logloss: 0.321583	valid_1's binary_logloss: 0.326021
# [400]	training's binary_logloss: 0.32017	valid_1's binary_logloss: 0.325894
# [500]	training's binary_logloss: 0.318792	valid_1's binary_logloss: 0.325958
# [600]	training's binary_logloss: 0.317446	valid_1's binary_logloss: 0.325945
# Early stopping, best iteration is:
# [415]	training's binary_logloss: 0.319965	valid_1's binary_logloss: 0.325872
# 0.5230389464572633
# Fold 7 started at Sat Mar 16 11:57:38 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.324529	valid_1's binary_logloss: 0.326105
# [200]	training's binary_logloss: 0.323018	valid_1's binary_logloss: 0.32595
# [300]	training's binary_logloss: 0.321592	valid_1's binary_logloss: 0.325882
# [400]	training's binary_logloss: 0.32018	valid_1's binary_logloss: 0.325851
# [500]	training's binary_logloss: 0.318839	valid_1's binary_logloss: 0.325897
# [600]	training's binary_logloss: 0.31751	valid_1's binary_logloss: 0.325918
# Early stopping, best iteration is:
# [427]	training's binary_logloss: 0.319809	valid_1's binary_logloss: 0.325831
# 0.5220795688041172
# Fold 8 started at Sat Mar 16 11:58:19 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.324497	valid_1's binary_logloss: 0.32606
# [200]	training's binary_logloss: 0.322982	valid_1's binary_logloss: 0.326005
# [300]	training's binary_logloss: 0.321536	valid_1's binary_logloss: 0.326095
# Early stopping, best iteration is:
# [170]	training's binary_logloss: 0.323416	valid_1's binary_logloss: 0.325961
# 0.5150723080213525
# Fold 9 started at Sat Mar 16 11:58:46 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.324538	valid_1's binary_logloss: 0.325979
# [200]	training's binary_logloss: 0.323022	valid_1's binary_logloss: 0.325994
# Early stopping, best iteration is:
# [55]	training's binary_logloss: 0.325234	valid_1's binary_logloss: 0.325948
# 0.5178956231145504
# 0.5158206093849933

# %%
version = 'kh_lgb_10fold_raw_shuffle_by_row'

pd.to_pickle(oof, 'oof+submission/'+version+'_oof_train')
pd.to_pickle(prediction, 'oof+submission/'+version+'_oof_test')    
sub = pd.DataFrame({"ID_code": test.ID_code.values})
sub["target"] = prediction
sub.to_csv('oof+submission/' + version + '_' + str(full_auc).replace('.', '_') + ".csv", index=False)

pd.options.display.max_rows=600
mean_gain = feature_importance_df[['importance', 'Feature']].groupby('Feature').mean().sort_values('importance', ascending=False)
mean_gain
# Out:
#          importance
# Feature
# var_9    238.430357
# var_125  224.617348
# var_110  223.318220
# var_152  210.297254
# var_3    201.775119
# var_79   201.602307
# var_19   194.435664
# var_78   190.340746
# var_66   170.956338
# var_71   170.448372
# var_142  168.302018
# var_128  166.019441
# var_28   159.040909
# var_45   157.426423
# var_144  152.563059
# var_53   151.350396
# var_59   150.113512
# var_137  148.050007
# var_46   144.710325
# var_109  144.327493
# var_6    142.491944
# var_178  142.109060
# var_155  139.766061
# var_73   139.119534
# var_123  137.990211
# var_168  137.916840
# var_87   136.817011
# var_50   136.382152
# var_183  135.660751
# var_67   133.158132
# var_146  132.490965
# var_195  129.882717
# var_38   128.373261
# var_131  128.358737
# var_102  126.433532
# var_160  126.124294
# var_52   126.032051
# var_124  124.998552
# var_162  124.625903
# var_23   123.916768
# var_138  122.858567
# var_62   122.443772
# var_118  122.122688
# var_20   121.821791
# var_179  119.903779
# var_94   119.090165
# var_90   118.781110
# var_143  118.135732
# var_108  117.740494
# var_199  117.467569
# var_92   117.210825
# var_0    116.191240
# var_122  116.057217
# var_36   115.186737
# var_151  114.543772
# var_41   113.208115
# var_166  112.520596
# var_83   110.291513
# var_115  109.328010
# var_37   107.394145
# var_68   106.170314
# var_198  105.148187
# var_77   105.078730
# var_100  104.675261
# var_1    104.666021
# var_148  102.995863
# var_10   102.643052
# var_21   101.321325
# var_58   101.202180
# var_173  100.798181
# var_96    98.907710
# var_174   98.264594
# var_182   98.100747
# var_76    96.693422
# var_31    96.372870
# var_34    94.672997
# var_99    94.658771
# var_158   94.570954
# var_120   93.822246
# var_8     93.201073
# var_26    92.462418
# var_98    91.920787
# var_101   89.937928
# var_54    88.878386
# var_153   88.595451
# var_129   88.238084
# var_175   87.987211
# var_130   87.539913
# var_164   86.915173
# var_7     86.662291
# var_12    86.496214
# var_116   85.704780
# var_27    84.333464
# var_55    84.111570
# var_185   83.445114
# var_111   83.209219
# var_35    83.090784
# var_40    82.685535
# var_63    81.645192
# var_171   80.736592
# var_113   78.815620
# var_44    78.387154
# var_33    78.238172
# var_47    77.337367
# var_186   77.336070
# var_80    77.176231
# var_167   77.150590
# var_72    76.191100
# var_192   75.330702
# var_85    75.107246
# var_117   73.960597
# var_187   73.471457
# var_119   73.161380
# var_105   72.959254
# var_121   72.615614
# var_103   71.731334
# var_132   70.625177
# var_135   70.210718
# var_25    70.049295
# var_190   69.946666
# var_107   69.363918
# var_48    68.913750
# var_163   68.065825
# var_191   66.922921
# var_177   66.656386
# var_97    66.422961
# var_141   66.016498
# var_74    65.416650
# var_91    65.147771
# var_126   64.608982
# var_2     64.467774
# var_180   64.453269
# var_133   64.167240
# var_95    63.915443
# var_29    63.557790
# var_156   63.518895
# var_69    63.300708
# var_169   63.106630
# var_93    62.987871
# var_81    62.401213
# var_84    62.290401
# var_4     61.969722
# var_196   61.896167
# var_184   61.895450
# var_88    61.879930
# var_127   61.638240
# var_13    61.550430
# var_139   61.284062
# var_42    61.039061
# var_57    60.766280
# var_165   60.541422
# var_145   60.428520
# var_112   59.886010
# var_64    59.433330
# var_159   59.425298
# var_14    59.038609
# var_18    58.724370
# var_140   58.077702
# var_176   57.961020
# var_181   57.696039
# var_194   57.216973
# var_86    57.136752
# var_24    56.575922
# var_65    55.987596
# var_197   55.476849
# var_5     55.468622
# var_147   55.214439
# var_114   54.594770
# var_161   53.768320
# var_39    53.189166
# var_75    52.596113
# var_11    52.411646
# var_49    51.487744
# var_170   51.418332
# var_17    50.792566
# var_149   50.523344
# var_134   50.109784
# var_61    49.415260
# var_188   49.189335
# var_193   48.409029
# var_30    48.302554
# var_104   45.308290
# var_56    44.874970
# var_150   44.812710
# var_89    43.971057
# var_70    43.332097
# var_51    43.239250
# var_136   43.158590
# var_15    42.982390
# var_154   42.481040
# var_60    41.213910
# var_157   40.715437
# var_172   40.579912
# var_189   39.368810
# var_22    39.344421
# var_16    37.632251
# var_32    36.795072
# var_106   35.003668
# var_43    34.438678
# var_82    28.038690
