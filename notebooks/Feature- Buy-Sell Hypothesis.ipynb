# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm import tqdm; tqdm.pandas()
pd.options.display.max_columns = 202
pd.options.display.max_rows = 300

# %%
train = pd.read_pickle('data/train_original.pkl')
test = pd.read_pickle('data/test_original.pkl')
special_cols = [col for col in train.columns if train[col].dtype != np.float64]
feature_cols = [col for col in train.columns if col not in special_cols]

# %%
all_df = pd.concat([train[feature_cols], test[feature_cols]], axis=0).reset_index(drop=True)

# %%
cumulative_vc = all_df[feature_cols[0]].value_counts()
cumulative_vc = cumulative_vc[cumulative_vc.index>0]

for col in tqdm(feature_cols[1:]):
    pos_filt, neg_filt = all_df[col]>0, all_df[col]<0
    vc = all_df[col].value_counts()
    
    all_df.loc[pos_filt, col+'_pos_pos_diff'] = all_df.loc[pos_filt, col].map(cumulative_vc).fillna(0) - \
                                                all_df.loc[pos_filt, col].map(vc)
    
    all_df.loc[neg_filt, col+'_pos_neg_diff'] = (all_df.loc[neg_filt, col]*-1).map(cumulative_vc).fillna(0) - \
                                                all_df.loc[neg_filt, col].map(vc)
     
    pos_idx, neg_idx = vc.index[vc.index>0], vc.index[vc.index<0]
    
    comm_idx = np.intersect1d(pos_idx, cumulative_vc.index)
    new_idx = pos_idx[~pos_idx.isin(comm_idx)]
    cumulative_vc.loc[comm_idx] += vc.loc[comm_idx]
    cumulative_vc = cumulative_vc.append(vc.loc[new_idx])   
    
    comm_idx = np.intersect1d(-1*neg_idx, cumulative_vc.index)
    new_idx = neg_idx[~neg_idx.isin(-1*comm_idx)]
    cumulative_vc.loc[comm_idx] -= vc.loc[-1*comm_idx].values
    new_vc = pd.Series(index=new_idx*-1, data=vc.loc[new_idx].values*-1)
    cumulative_vc = cumulative_vc.append(new_vc)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 199/199 [09:24<00:00,  4.12s/it]

# %%
feat_cols = [c for c in all_df.columns if '_diff' in c]
all_df[feat_cols].nunique()
# Out:
# var_1_pos_pos_diff       36
# var_1_pos_neg_diff       38
# var_2_pos_pos_diff       41
# var_2_pos_neg_diff        0
# var_3_pos_pos_diff       57
# var_3_pos_neg_diff        2
# var_4_pos_pos_diff       62
# var_4_pos_neg_diff        0
# var_5_pos_pos_diff       67
# var_5_pos_neg_diff       70
# var_6_pos_pos_diff       79
# var_6_pos_neg_diff        0
# var_7_pos_pos_diff       68
# var_7_pos_neg_diff        0
# var_8_pos_pos_diff       80
# var_8_pos_neg_diff       80
# var_9_pos_pos_diff       80
# var_9_pos_neg_diff        0
# var_10_pos_pos_diff      95
# var_10_pos_neg_diff      95
# var_11_pos_pos_diff      95
# var_11_pos_neg_diff      97
# var_12_pos_pos_diff     149
# var_12_pos_neg_diff       0
# var_13_pos_pos_diff     170
# var_13_pos_neg_diff      59
# var_14_pos_pos_diff     112
# var_14_pos_neg_diff       0
# var_15_pos_pos_diff     183
# var_15_pos_neg_diff       0
# var_16_pos_pos_diff     183
# var_16_pos_neg_diff       0
# var_17_pos_pos_diff     130
# var_17_pos_neg_diff     195
# var_18_pos_pos_diff     198
# var_18_pos_neg_diff      80
# var_19_pos_pos_diff     193
# var_19_pos_neg_diff      98
# var_20_pos_pos_diff     202
# var_20_pos_neg_diff      37
# var_21_pos_pos_diff     197
# var_21_pos_neg_diff      92
# var_22_pos_pos_diff     132
# var_22_pos_neg_diff      71
# var_23_pos_pos_diff     124
# var_23_pos_neg_diff       0
# var_24_pos_pos_diff     190
# var_24_pos_neg_diff      10
# var_25_pos_pos_diff     225
# var_25_pos_neg_diff       0
# var_26_pos_pos_diff     128
# var_26_pos_neg_diff     233
# var_27_pos_pos_diff     103
# var_27_pos_neg_diff     127
# var_28_pos_pos_diff     110
# var_28_pos_neg_diff       0
# var_29_pos_pos_diff     155
# var_29_pos_neg_diff      83
# var_30_pos_pos_diff     163
# var_30_pos_neg_diff     250
# var_31_pos_pos_diff     220
# var_31_pos_neg_diff       0
# var_32_pos_pos_diff     160
# var_32_pos_neg_diff     166
# var_33_pos_pos_diff     224
# var_33_pos_neg_diff       0
# var_34_pos_pos_diff     110
# var_34_pos_neg_diff       0
# var_35_pos_pos_diff     248
# var_35_pos_neg_diff     165
# var_36_pos_pos_diff     175
# var_36_pos_neg_diff     160
# var_37_pos_pos_diff     169
# var_37_pos_neg_diff      44
# var_38_pos_pos_diff     257
# var_38_pos_neg_diff      96
# var_39_pos_pos_diff     196
# var_39_pos_neg_diff     185
# var_40_pos_pos_diff     197
# var_40_pos_neg_diff     257
# var_41_pos_pos_diff     260
# var_41_pos_neg_diff     153
# var_42_pos_pos_diff     112
# var_42_pos_neg_diff       0
# var_43_pos_pos_diff     141
# var_43_pos_neg_diff       0
# var_44_pos_pos_diff     266
# var_44_pos_neg_diff     179
# var_45_pos_pos_diff     254
# var_45_pos_neg_diff     258
# var_46_pos_pos_diff     235
# var_46_pos_neg_diff       0
# var_47_pos_pos_diff     233
# var_47_pos_neg_diff     273
# var_48_pos_pos_diff     267
# var_48_pos_neg_diff     236
# var_49_pos_pos_diff     267
# var_49_pos_neg_diff     142
# var_50_pos_pos_diff     245
# var_50_pos_neg_diff       0
# var_51_pos_pos_diff     284
# var_51_pos_neg_diff     183
# var_52_pos_pos_diff     227
# var_52_pos_neg_diff     268
# var_53_pos_pos_diff     136
# var_53_pos_neg_diff       0
# var_54_pos_pos_diff     279
# var_54_pos_neg_diff     269
# var_55_pos_pos_diff     276
# var_55_pos_neg_diff      77
# var_56_pos_pos_diff     255
# var_56_pos_neg_diff       0
# var_57_pos_pos_diff     151
# var_57_pos_neg_diff       0
# var_58_pos_pos_diff     277
# var_58_pos_neg_diff     235
# var_59_pos_pos_diff     181
# var_59_pos_neg_diff       0
# var_60_pos_pos_diff     272
# var_60_pos_neg_diff      11
# var_61_pos_pos_diff     271
# var_61_pos_neg_diff     290
# var_62_pos_pos_diff     249
# var_62_pos_neg_diff     205
# var_63_pos_pos_diff     254
# var_63_pos_neg_diff     252
# var_64_pos_pos_diff     203
# var_64_pos_neg_diff       0
# var_65_pos_pos_diff     269
# var_65_pos_neg_diff     264
# var_66_pos_pos_diff     210
# var_66_pos_neg_diff       0
# var_67_pos_pos_diff     305
# var_67_pos_neg_diff     255
# var_68_pos_pos_diff     382
# var_68_pos_neg_diff       0
# var_69_pos_pos_diff     388
# var_69_pos_neg_diff     579
# var_70_pos_pos_diff     390
# var_70_pos_neg_diff     242
# var_71_pos_pos_diff     170
# var_71_pos_neg_diff      79
# var_72_pos_pos_diff     544
# var_72_pos_neg_diff     505
# var_73_pos_pos_diff     365
# var_73_pos_neg_diff      11
# var_74_pos_pos_diff     406
# var_74_pos_neg_diff     306
# var_75_pos_pos_diff     356
# var_75_pos_neg_diff       9
#                        ...
# var_125_pos_pos_diff    230
# var_125_pos_neg_diff      0
# var_126_pos_pos_diff    334
# var_126_pos_neg_diff      0
# var_127_pos_pos_diff    675
# var_127_pos_neg_diff    559
# var_128_pos_pos_diff    545
# var_128_pos_neg_diff    686
# var_129_pos_pos_diff    438
# var_129_pos_neg_diff      0
# var_130_pos_pos_diff    318
# var_130_pos_neg_diff      0
# var_131_pos_pos_diff    295
# var_131_pos_neg_diff    221
# var_132_pos_pos_diff    507
# var_132_pos_neg_diff      0
# var_133_pos_pos_diff    230
# var_133_pos_neg_diff      0
# var_134_pos_pos_diff    584
# var_134_pos_neg_diff    737
# var_135_pos_pos_diff    627
# var_135_pos_neg_diff    713
# var_136_pos_pos_diff    545
# var_136_pos_neg_diff    266
# var_137_pos_pos_diff    609
# var_137_pos_neg_diff    305
# var_138_pos_pos_diff    732
# var_138_pos_neg_diff    658
# var_139_pos_pos_diff    709
# var_139_pos_neg_diff    543
# var_140_pos_pos_diff    750
# var_140_pos_neg_diff    618
# var_141_pos_pos_diff    718
# var_141_pos_neg_diff    661
# var_142_pos_pos_diff    691
# var_142_pos_neg_diff    252
# var_143_pos_pos_diff    529
# var_143_pos_neg_diff      0
# var_144_pos_pos_diff    328
# var_144_pos_neg_diff      0
# var_145_pos_pos_diff    771
# var_145_pos_neg_diff    375
# var_146_pos_pos_diff    564
# var_146_pos_neg_diff      0
# var_147_pos_pos_diff    666
# var_147_pos_neg_diff    720
# var_148_pos_pos_diff    243
# var_148_pos_neg_diff      0
# var_149_pos_pos_diff    705
# var_149_pos_neg_diff    616
# var_150_pos_pos_diff    430
# var_150_pos_neg_diff      0
# var_151_pos_pos_diff    709
# var_151_pos_neg_diff     94
# var_152_pos_pos_diff    777
# var_152_pos_neg_diff    229
# var_153_pos_pos_diff    432
# var_153_pos_neg_diff      0
# var_154_pos_pos_diff    762
# var_154_pos_neg_diff    433
# var_155_pos_pos_diff    673
# var_155_pos_neg_diff    757
# var_156_pos_pos_diff    387
# var_156_pos_neg_diff      0
# var_157_pos_pos_diff    603
# var_157_pos_neg_diff    787
# var_158_pos_pos_diff    588
# var_158_pos_neg_diff    109
# var_159_pos_pos_diff    729
# var_159_pos_neg_diff    214
# var_160_pos_pos_diff    585
# var_160_pos_neg_diff    170
# var_161_pos_pos_diff    316
# var_161_pos_neg_diff      0
# var_162_pos_pos_diff    705
# var_162_pos_neg_diff      0
# var_163_pos_pos_diff    758
# var_163_pos_neg_diff    274
# var_164_pos_pos_diff    674
# var_164_pos_neg_diff    763
# var_165_pos_pos_diff    471
# var_165_pos_neg_diff      0
# var_166_pos_pos_diff    291
# var_166_pos_neg_diff      0
# var_167_pos_pos_diff    674
# var_167_pos_neg_diff    751
# var_168_pos_pos_diff    807
# var_168_pos_neg_diff    329
# var_169_pos_pos_diff    554
# var_169_pos_neg_diff      0
# var_170_pos_pos_diff    752
# var_170_pos_neg_diff    761
# var_171_pos_pos_diff    747
# var_171_pos_neg_diff    785
# var_172_pos_pos_diff    611
# var_172_pos_neg_diff    359
# var_173_pos_pos_diff    731
# var_173_pos_neg_diff    764
# var_174_pos_pos_diff    529
# var_174_pos_neg_diff     97
# var_175_pos_pos_diff    490
# var_175_pos_neg_diff      0
# var_176_pos_pos_diff    712
# var_176_pos_neg_diff    782
# var_177_pos_pos_diff    459
# var_177_pos_neg_diff      0
# var_178_pos_pos_diff    732
# var_178_pos_neg_diff    741
# var_179_pos_pos_diff    808
# var_179_pos_neg_diff    453
# var_180_pos_pos_diff    694
# var_180_pos_neg_diff    796
# var_181_pos_pos_diff    335
# var_181_pos_neg_diff      0
# var_182_pos_pos_diff    750
# var_182_pos_neg_diff    748
# var_183_pos_pos_diff    810
# var_183_pos_neg_diff    316
# var_184_pos_pos_diff    715
# var_184_pos_neg_diff    558
# var_185_pos_pos_diff    659
# var_185_pos_neg_diff    818
# var_186_pos_pos_diff    741
# var_186_pos_neg_diff     93
# var_187_pos_pos_diff    655
# var_187_pos_neg_diff    718
# var_188_pos_pos_diff    503
# var_188_pos_neg_diff      0
# var_189_pos_pos_diff    355
# var_189_pos_neg_diff    314
# var_190_pos_pos_diff    819
# var_190_pos_neg_diff    662
# var_191_pos_pos_diff    792
# var_191_pos_neg_diff    172
# var_192_pos_pos_diff    715
# var_192_pos_neg_diff    319
# var_193_pos_pos_diff    834
# var_193_pos_neg_diff    630
# var_194_pos_pos_diff    490
# var_194_pos_neg_diff      0
# var_195_pos_pos_diff    381
# var_195_pos_neg_diff    404
# var_196_pos_pos_diff    816
# var_196_pos_neg_diff    758
# var_197_pos_pos_diff    328
# var_197_pos_neg_diff      0
# var_198_pos_pos_diff    491
# var_198_pos_neg_diff      0
# var_199_pos_pos_diff    738
# var_199_pos_neg_diff    758
# Length: 398, dtype: int64

# %%
unique_cols = [c for c in all_df.columns[1:] if '_diff' not in c and all_df[c+'_pos_neg_diff'].nunique()==0]
for col in unique_cols:
    vc = all_df[col].value_counts()
    print(col, vc[vc.index<0])
# Out:
# var_2 Series([], Name: var_2, dtype: int64)
# var_4 Series([], Name: var_4, dtype: int64)
# var_6 Series([], Name: var_6, dtype: int64)
# var_7 Series([], Name: var_7, dtype: int64)
# var_9 Series([], Name: var_9, dtype: int64)
# var_12 Series([], Name: var_12, dtype: int64)
# var_14 Series([], Name: var_14, dtype: int64)
# var_15 Series([], Name: var_15, dtype: int64)
# var_16 Series([], Name: var_16, dtype: int64)
# var_23 Series([], Name: var_23, dtype: int64)
# var_25 Series([], Name: var_25, dtype: int64)
# var_28 Series([], Name: var_28, dtype: int64)
# var_31 Series([], Name: var_31, dtype: int64)
# var_33 Series([], Name: var_33, dtype: int64)
# var_34 Series([], Name: var_34, dtype: int64)
# var_42 Series([], Name: var_42, dtype: int64)
# var_43 Series([], Name: var_43, dtype: int64)
# var_46 Series([], Name: var_46, dtype: int64)
# var_50 Series([], Name: var_50, dtype: int64)
# var_53 Series([], Name: var_53, dtype: int64)
# var_56 Series([], Name: var_56, dtype: int64)
# var_57 Series([], Name: var_57, dtype: int64)
# var_59 Series([], Name: var_59, dtype: int64)
# var_64 Series([], Name: var_64, dtype: int64)
# var_66 Series([], Name: var_66, dtype: int64)
# var_68 Series([], Name: var_68, dtype: int64)
# var_77 Series([], Name: var_77, dtype: int64)
# var_79 Series([], Name: var_79, dtype: int64)
# var_81 Series([], Name: var_81, dtype: int64)
# var_85 Series([], Name: var_85, dtype: int64)
# var_88 Series([], Name: var_88, dtype: int64)
# var_91 Series([], Name: var_91, dtype: int64)
# var_93 Series([], Name: var_93, dtype: int64)
# var_94 Series([], Name: var_94, dtype: int64)
# var_103 Series([], Name: var_103, dtype: int64)
# var_104 Series([], Name: var_104, dtype: int64)
# var_105 Series([], Name: var_105, dtype: int64)
# var_106 Series([], Name: var_106, dtype: int64)
# var_108 Series([], Name: var_108, dtype: int64)
# var_109 Series([], Name: var_109, dtype: int64)
# var_111 Series([], Name: var_111, dtype: int64)
# var_121 Series([], Name: var_121, dtype: int64)
# var_125 Series([], Name: var_125, dtype: int64)
# var_126 Series([], Name: var_126, dtype: int64)
# var_129 Series([], Name: var_129, dtype: int64)
# var_130 Series([], Name: var_130, dtype: int64)
# var_132 Series([], Name: var_132, dtype: int64)
# var_133 Series([], Name: var_133, dtype: int64)
# var_143 Series([], Name: var_143, dtype: int64)
# var_144 Series([], Name: var_144, dtype: int64)
# var_146 Series([], Name: var_146, dtype: int64)
# var_148 Series([], Name: var_148, dtype: int64)
# var_150 Series([], Name: var_150, dtype: int64)
# var_153 Series([], Name: var_153, dtype: int64)
# var_156 Series([], Name: var_156, dtype: int64)
# var_161 Series([], Name: var_161, dtype: int64)
# var_162 Series([], Name: var_162, dtype: int64)
# var_165 Series([], Name: var_165, dtype: int64)
# var_166 Series([], Name: var_166, dtype: int64)
# var_169 Series([], Name: var_169, dtype: int64)
# var_175 Series([], Name: var_175, dtype: int64)
# var_177 Series([], Name: var_177, dtype: int64)
# var_181 Series([], Name: var_181, dtype: int64)
# var_188 Series([], Name: var_188, dtype: int64)
# var_194 Series([], Name: var_194, dtype: int64)
# var_197 Series([], Name: var_197, dtype: int64)
# var_198 Series([], Name: var_198, dtype: int64)

# %%
selected_feats = [c for c in all_df.columns if '_diff' in c and all_df[c].nunique()!=0]
len(selected_feats)
# Out:
# 331

# %%
all_df[selected_feats].iloc[:train.shape[0]].to_pickle('features/buy_sell_feat_train.pkl')
all_df[selected_feats].iloc[train.shape[0]:].reset_index(drop=True).to_pickle('features/buy_sell_feat_test.pkl')
