# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm import tqdm; tqdm.pandas()
pd.options.display.max_columns = 202
pd.options.display.max_rows = 300

# %%
train = pd.read_pickle('data/train_original.pkl')
test = pd.read_pickle('data/test_original.pkl')
special_cols = [col for col in train.columns if train[col].dtype != np.float64]
feature_cols = [col for col in train.columns if col not in special_cols]

# %%
train.drop(special_cols[0], axis=1, inplace=True)
test.drop(special_cols[0], axis=1, inplace=True)

unique_samples = []
unique_count = np.zeros_like(test)
for feature in tqdm(range(test.shape[1])):
    _, index_, count_ = np.unique(test.values[:, feature], return_counts=True, return_index=True)
    unique_count[index_[count_ == 1], feature] += 1

# Samples which have unique values are real the others are fake
real_samples_indexes = np.argwhere(np.sum(unique_count, axis=1) > 0)[:, 0]
synthetic_samples_indexes = np.argwhere(np.sum(unique_count, axis=1) == 0)[:, 0]

real_test=test.iloc[real_samples_indexes].reset_index(drop=True)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 200/200 [00:06<00:00, 30.05it/s]

# %%
for col in tqdm(feature_cols):
    vc = train[col].append(real_test[col]).value_counts()
    vc_df = pd.DataFrame(index=vc.index)
    vc_df['count'] = vc.values
    vc_df = vc_df.sort_index(ascending=True)
    vc_df['opposite_count'] = vc_df['count'].values[-1::-1]
    vc_df['count_opposite_diff'] = vc_df['count']-vc_df['opposite_count']
    train[col+'_cnt_enc'] = train[col].map(vc_df['count_opposite_diff'])
    test[col+'_cnt_enc'] = test[col].map(vc_df['count_opposite_diff'])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 200/200 [00:18<00:00,  5.41it/s]

# %%
new_feats = [f+'_cnt_enc' for f in feature_cols]
for df in [train, test]:
    df['cnt_enc_sum'] = df[new_feats].sum(axis=1)
    df['cnt_enc_std'] = df[new_feats].std(axis=1)
new_feats += ['cnt_enc_sum', 'cnt_enc_std']

# %%
train[['target']+new_feats].iloc[:10000].corr('spearman').sort_values('target', ascending=False)[['target']]
# Out:
#                    target
# target           1.000000
# var_183_cnt_enc  0.023054
# var_134_cnt_enc  0.022830
# var_53_cnt_enc   0.020099
# var_120_cnt_enc  0.018373
# var_193_cnt_enc  0.018119
# var_97_cnt_enc   0.018007
# var_197_cnt_enc  0.017847
# cnt_enc_sum      0.017398
# var_12_cnt_enc   0.017199
# var_199_cnt_enc  0.016230
# var_33_cnt_enc   0.015768
# var_32_cnt_enc   0.014966
# var_68_cnt_enc   0.014658
# var_172_cnt_enc  0.013989
# var_148_cnt_enc  0.013883
# var_157_cnt_enc  0.013525
# var_122_cnt_enc  0.013394
# var_22_cnt_enc   0.012464
# var_46_cnt_enc   0.012258
# var_85_cnt_enc   0.011736
# var_188_cnt_enc  0.011450
# var_18_cnt_enc   0.010012
# var_99_cnt_enc   0.009703
# var_175_cnt_enc  0.009682
# var_54_cnt_enc   0.009320
# var_92_cnt_enc   0.008558
# var_82_cnt_enc   0.008419
# var_144_cnt_enc  0.008156
# var_84_cnt_enc   0.008150
# var_161_cnt_enc  0.008028
# var_27_cnt_enc   0.007911
# cnt_enc_std      0.007872
# var_149_cnt_enc  0.007797
# var_159_cnt_enc  0.007748
# var_185_cnt_enc  0.007322
# var_36_cnt_enc   0.007318
# var_21_cnt_enc   0.006955
# var_158_cnt_enc  0.006893
# var_7_cnt_enc    0.006833
# var_195_cnt_enc  0.006768
# var_90_cnt_enc   0.006736
# var_182_cnt_enc  0.006682
# var_152_cnt_enc  0.006425
# var_79_cnt_enc   0.006330
# var_77_cnt_enc   0.006300
# var_14_cnt_enc   0.006297
# var_186_cnt_enc  0.006237
# var_108_cnt_enc  0.006050
# var_67_cnt_enc   0.006048
# var_169_cnt_enc  0.005684
# var_104_cnt_enc  0.005221
# var_180_cnt_enc  0.005015
# var_136_cnt_enc  0.004992
# var_112_cnt_enc  0.004926
# var_72_cnt_enc   0.004926
# var_117_cnt_enc  0.004875
# var_8_cnt_enc    0.004859
# var_75_cnt_enc   0.004745
# var_192_cnt_enc  0.004725
# var_100_cnt_enc  0.004704
# var_178_cnt_enc  0.003645
# var_191_cnt_enc  0.003632
# var_38_cnt_enc   0.003621
# var_56_cnt_enc   0.003531
# var_57_cnt_enc   0.003151
# var_116_cnt_enc  0.002795
# var_150_cnt_enc  0.002721
# var_171_cnt_enc  0.002625
# var_118_cnt_enc  0.002467
# var_23_cnt_enc   0.002292
# var_145_cnt_enc  0.002155
# var_176_cnt_enc  0.001997
# var_58_cnt_enc   0.001795
# var_164_cnt_enc  0.001667
# var_174_cnt_enc  0.001619
# var_87_cnt_enc   0.001431
# var_3_cnt_enc    0.001202
# var_24_cnt_enc   0.001189
# var_44_cnt_enc   0.001144
# var_177_cnt_enc  0.001103
# var_65_cnt_enc   0.000909
# var_48_cnt_enc   0.000815
# var_4_cnt_enc    0.000587
# var_78_cnt_enc   0.000425
# var_41_cnt_enc   0.000358
# var_179_cnt_enc -0.000090
# var_15_cnt_enc  -0.000128
# var_37_cnt_enc  -0.000511
# var_35_cnt_enc  -0.000547
# var_121_cnt_enc -0.000731
# var_29_cnt_enc  -0.000750
# var_47_cnt_enc  -0.000966
# var_184_cnt_enc -0.001066
# var_94_cnt_enc  -0.001253
# var_181_cnt_enc -0.001276
# var_96_cnt_enc  -0.001297
# var_187_cnt_enc -0.001324
# var_66_cnt_enc  -0.001368
# var_95_cnt_enc  -0.001404
# var_129_cnt_enc -0.001570
# var_39_cnt_enc  -0.001595
# var_107_cnt_enc -0.001985
# var_156_cnt_enc -0.002061
# var_132_cnt_enc -0.002086
# var_155_cnt_enc -0.002102
# var_55_cnt_enc  -0.002211
# var_103_cnt_enc -0.002314
# var_88_cnt_enc  -0.002365
# var_135_cnt_enc -0.002437
# var_69_cnt_enc  -0.002485
# var_198_cnt_enc -0.002835
# var_5_cnt_enc   -0.002923
# var_74_cnt_enc  -0.003039
# var_43_cnt_enc  -0.003101
# var_30_cnt_enc  -0.003262
# var_153_cnt_enc -0.003290
# var_194_cnt_enc -0.003293
# var_167_cnt_enc -0.003373
# var_0_cnt_enc   -0.003795
# var_160_cnt_enc -0.003871
# var_162_cnt_enc -0.003912
# var_59_cnt_enc  -0.004100
# var_110_cnt_enc -0.004470
# var_11_cnt_enc  -0.004531
# var_50_cnt_enc  -0.004612
# var_40_cnt_enc  -0.004685
# var_147_cnt_enc -0.004793
# var_151_cnt_enc -0.004910
# var_16_cnt_enc  -0.004957
# var_138_cnt_enc -0.005396
# var_109_cnt_enc -0.005509
# var_165_cnt_enc -0.005655
# var_31_cnt_enc  -0.005801
# var_101_cnt_enc -0.005841
# var_140_cnt_enc -0.005952
# var_89_cnt_enc  -0.006004
# var_80_cnt_enc  -0.006377
# var_83_cnt_enc  -0.006623
# var_102_cnt_enc -0.006643
# var_105_cnt_enc -0.006743
# var_119_cnt_enc -0.006938
# var_141_cnt_enc -0.006938
# var_42_cnt_enc  -0.006967
# var_146_cnt_enc -0.007084
# var_142_cnt_enc -0.007117
# var_64_cnt_enc  -0.007132
# var_1_cnt_enc   -0.007278
# var_166_cnt_enc -0.007403
# var_98_cnt_enc  -0.007885
# var_25_cnt_enc  -0.008226
# var_113_cnt_enc -0.008441
# var_28_cnt_enc  -0.008655
# var_6_cnt_enc   -0.008907
# var_190_cnt_enc -0.009017
# var_45_cnt_enc  -0.009145
# var_34_cnt_enc  -0.009180
# var_173_cnt_enc -0.009294
# var_106_cnt_enc -0.010273
# var_128_cnt_enc -0.010278
# var_86_cnt_enc  -0.010569
# var_26_cnt_enc  -0.010920
# var_81_cnt_enc  -0.011553
# var_170_cnt_enc -0.011872
# var_17_cnt_enc  -0.011948
# var_60_cnt_enc  -0.011995
# var_76_cnt_enc  -0.012294
# var_9_cnt_enc   -0.012813
# var_70_cnt_enc  -0.012841
# var_111_cnt_enc -0.012993
# var_163_cnt_enc -0.013054
# var_114_cnt_enc -0.013101
# var_124_cnt_enc -0.013238
# var_20_cnt_enc  -0.013284
# var_52_cnt_enc  -0.013827
# var_49_cnt_enc  -0.013844
# var_196_cnt_enc -0.014142
# var_71_cnt_enc  -0.015009
# var_137_cnt_enc -0.015164
# var_126_cnt_enc -0.015327
# var_115_cnt_enc -0.015363
# var_13_cnt_enc  -0.015532
# var_130_cnt_enc -0.015619
# var_10_cnt_enc  -0.015815
# var_168_cnt_enc -0.016427
# var_154_cnt_enc -0.016439
# var_19_cnt_enc  -0.017292
# var_73_cnt_enc  -0.017671
# var_61_cnt_enc  -0.017711
# var_133_cnt_enc -0.017856
# var_125_cnt_enc -0.018286
# var_91_cnt_enc  -0.018340
# var_51_cnt_enc  -0.018658
# var_63_cnt_enc  -0.019038
# var_139_cnt_enc -0.020460
# var_189_cnt_enc -0.021172
# var_123_cnt_enc -0.022934
# var_131_cnt_enc -0.023062
# var_93_cnt_enc  -0.023302
# var_2_cnt_enc   -0.023693
# var_143_cnt_enc -0.024642
# var_62_cnt_enc  -0.027317
# var_127_cnt_enc -0.028253

# %%
train[new_feats].to_pickle('features/per_feature_opposite_rank_count_encode_train_v2.pkl')
test[new_feats].to_pickle('features/per_feature_opposite_rank_count_encode_test_v2.pkl')
